# %%
import pandas as pd 
import json 
from datetime import datetime

# %%
    with open("turbidity_data.json", 'r') as f:
        water_data = json.load(f)

# %%
water_data
# Out:
# {'turbidity_data': [{'datetime': '2022-02-01 00:00',
#    'sample_volume': 1.19,
#    'calibration_constant': 1.022,
#    'detector_current': 1.137,
#    'analyzed_by': 'C. Milligan'},
#   {'datetime': '2022-02-01 01:00',
#    'sample_volume': 1.15,
#    'calibration_constant': 0.975,
#    'detector_current': 1.141,
#    'analyzed_by': 'C. Milligan'},
#   {'datetime': '2022-02-01 02:00',
#    'sample_volume': 1.15,
#    'calibration_constant': 1.022,
#    'detector_current': 1.1300000000000001,
#    'analyzed_by': 'C. Milligan'},
#   {'datetime': '2022-02-01 03:00',
#    'sample_volume': 1.18,
#    'calibration_constant': 0.989,
#    'detector_current': 1.129,
#    'analyzed_by': 'R. Zhang'},
#   {'datetime': '2022-02-01 04:00',
#    'sample_volume': 1.19,
#    'calibration_constant': 1.029,
#    'detector_current': 1.189,
#    'analyzed_by': 'J. Maertz'},
#   {'datetime': '2022-02-01 05:00',
#    'sample_volume': 1.17,
#    'calibration_constant': 1.01,
# ...

# %%
date_time = datetime(2022, 2, 12, 14)

# %%
date_time
# Out:
# datetime.datetime(2022, 2, 12, 14, 0)

# %%
d = water_data['turbidity_data'][0]

# %%
type(d['datetime'])
# Out:
# str

# %%
lst = water_data['turbidity_data']

# %%
indexes = next((index for (index, d) in enumerate(lst) if d["datetime"] == '2022-02-01 02:00'), None)

# %%
type(indexes)
# Out:
# int
